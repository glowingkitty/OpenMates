# %% [markdown]
# # Google Places API Test
#
# This notebook tests the Google Places API (Text Search) and demonstrates how to copy the JSON response to the clipboard.
#
# **Setup:**
# 1.  Install the required Python libraries: `pip install requests`
# 2.  Get a Google Cloud API Key with the **Places API** enabled.
# 3.  Enter your API Key and search query in the cell below.

# %%
# %pip install requests dotenv
# Out:
# Requirement already satisfied: requests in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: dotenv in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (0.9.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: python-dotenv in /home/superdev/projects/OpenMates/tree-sitter-env/lib/python3.12/site-packages (from dotenv) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Get API key from environment variable
import os
import pathlib
from dotenv import load_dotenv

# Try to find the project root (where .env is located)
current_dir = pathlib.Path.cwd()
# Look for .env in parent directories
found = False
for parent in [current_dir] + list(current_dir.parents):
    env_path = parent / '.env'
    if env_path.exists():
        print(f"Loading .env from {env_path}")
        load_dotenv(env_path)
        found = True
        break

API_KEY = os.getenv('SECRET__GOOGLE_MAPS__API_KEY')
if not API_KEY:
    raise ValueError("Google Maps API key is not set. Please set the SECRET__GOOGLE_MAPS__API_KEY environment variable.")
# Out:
# Loading .env from /home/superdev/projects/OpenMates/.env

# %%
# Define your search query.
search_query = "Museums in Berlin, Germany"

# Define the fields you want the API to return.
# For a full list, see the Place (New) API documentation.
fields_to_return = [
    'places.displayName',
    'places.formattedAddress',
    'places.location',
    'places.rating',
    'places.websiteUri',
    'places.reviews'
]

# ⬆️ =============================== ⬆️

print("✅ Inputs loaded.")
# Out:
# ✅ Inputs loaded.

# %% [markdown]
# ## 2. Make the API Request
#
# This cell constructs and sends the request to the Google Places API endpoint.

# %%
import requests
import json

# The new Text Search API endpoint
url = "https://places.googleapis.com/v1/places:searchText"

# Prepare the request payload and headers
payload = {
    "textQuery": search_query
}

headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': API_KEY,
    'X-Goog-FieldMask': ','.join(fields_to_return)
}


payload_str = json.dumps(payload)
header_str = json.dumps(headers)

print(f"🔍 Searching for: '{search_query}'...")

# Make the POST request
url = "https://places.googleapis.com/v1/places:searchText"
response = requests.post(url, json=payload, headers=headers)

# Process the response
print(f"\n📦 Status Code: {response.status_code}")
if response.status_code == 200:
    response_json = response.json()
    print("\n✅ API Response:")
    print(json.dumps(response_json, indent=2))
else:
    print("\n❌ Error fetching data:")
    print(response.text)
# Out:
# 🔍 Searching for: 'Museums in Berlin, Germany'...
#
# 📦 Status Code: 200
#
# ✅ API Response:
# {
#   "places": [
#     {
#       "formattedAddress": "Bodestra\u00dfe 1-3, 10178 Berlin, Germany",
#       "location": {
#         "latitude": 52.520134899999995,
#         "longitude": 13.397646199999999
#       },
#       "rating": 4.5,
#       "websiteUri": "https://www.smb.museum/museen-einrichtungen/neues-museum/home/",
#       "displayName": {
#         "text": "Neues Museum",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJS8OUk91RqEcRNauNAPV5P40/reviews/Ci9DQUlRQUNvZENodHljRjlvT2s4eWRrZ3phSGRPZFd4aVVXdFpiVFpYYVhob2VrRRAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 4,
#           "text": {
#             "text": "The museum holds Nefertiti's bust and we went to see it. There are also other interesting artifacts, mainly Egyptian. Also I recommend to pay attention to the restored building interior. The staff was obsessed about the security and overreacted without visible reason. You have to leave everything in the dress room so you can visit the museum peacefully.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "The museum holds Nefertiti's bust and we went to see it. There are also other interesting artifacts, mainly Egyptian. Also I recommend to pay attention to the restored building interior. The staff was obsessed about the security and overreacted without visible reason. You have to leave everything in the dress room so you can visit the museum peacefully.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Elena Kotsinova",
#             "uri": "https://www.google.com/maps/contrib/100366105188223754464/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUxCLcizHKN_a8WmwfIh1uaeRhW0hYjyqtq9-zZW4pNY8Batbolpg=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-07-16T05:46:57.734307385Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2s4eWRrZ3phSGRPZFd4aVVXdFpiVFpYYVhob2VrRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2s4eWRrZ3phSGRPZFd4aVVXdFpiVFpYYVhob2VrRRAB!2m1!1s0x47a851dd9394c34b:0x8d3f79f5008dab35"
#         },
#         {
#           "name": "places/ChIJS8OUk91RqEcRNauNAPV5P40/reviews/ChZDSUhNMG9nS0VObVJsOXJILTZQMEJREAE",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 4,
#           "text": {
#             "text": "Instructions to enter were not clear. Apparently, if you book ahead of time, you get to skip the line, but we were made to wait. Then later located and offered to skip the line. Lines are regardless of time of day. The Egyptian Museum and Papyrus Collection seemed to be popular. Check in agents were swift and helpful. There was also a complimentary coat checkin available.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Instructions to enter were not clear. Apparently, if you book ahead of time, you get to skip the line, but we were made to wait. Then later located and offered to skip the line. Lines are regardless of time of day. The Egyptian Museum and Papyrus Collection seemed to be popular. Check in agents were swift and helpful. There was also a complimentary coat checkin available.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Christabella",
#             "uri": "https://www.google.com/maps/contrib/106791160516184615997/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXoRfWphID30ry7E1wuAO2QeRtRCDBF67ZxKNbK3XpfyhiCCQOB=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2025-06-15T01:25:36.407736Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VObVJsOXJILTZQMEJREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VObVJsOXJILTZQMEJREAE!2m1!1s0x47a851dd9394c34b:0x8d3f79f5008dab35"
#         },
#         {
#           "name": "places/ChIJS8OUk91RqEcRNauNAPV5P40/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZaUxqTkxBEAE",
#           "relativePublishTimeDescription": "2 months ago",
#           "rating": 5,
#           "text": {
#             "text": "The museum presents a great collection of unique Egyptian artifacts to the public. I highly recommend a visit to anyone interested in art history. I was pleasantly surprised that my son, who had never shown much interest in art and culture before, found this museum fascinating. Many thanks to everyone who helps preserve this wonderful collection.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "The museum presents a great collection of unique Egyptian artifacts to the public. I highly recommend a visit to anyone interested in art history. I was pleasantly surprised that my son, who had never shown much interest in art and culture before, found this museum fascinating. Many thanks to everyone who helps preserve this wonderful collection.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Anastasiya Petrushchenkova",
#             "uri": "https://www.google.com/maps/contrib/108214714133024929653/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUJTaWNzgyzs18CcC8yO3YCeS6paPqOofs7xFM0OuPykr5bAiaylQ=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-20T11:48:00.956138Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZaUxqTkxBEAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZaUxqTkxBEAE!2m1!1s0x47a851dd9394c34b:0x8d3f79f5008dab35"
#         },
#         {
#           "name": "places/ChIJS8OUk91RqEcRNauNAPV5P40/reviews/ChZDSUhNMG9nS0VJQ0FnTURvaDdha1R3EAE",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 5,
#           "text": {
#             "text": "Even though I didn\u2019t get to go inside, the Neues Museum in Berlin was stunning from the outside. The historic architecture is beautifully restored, and the lush green garden surrounding it adds a peaceful, charming ambiance. It\u2019s worth a visit just to admire the exterior and soak in the serene atmosphere.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Even though I didn\u2019t get to go inside, the Neues Museum in Berlin was stunning from the outside. The historic architecture is beautifully restored, and the lush green garden surrounding it adds a peaceful, charming ambiance. It\u2019s worth a visit just to admire the exterior and soak in the serene atmosphere.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Muaz Kabir",
#             "uri": "https://www.google.com/maps/contrib/112329902269680168736/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWLcZShWfBw9WikKKh5fko5_A3F7a-CtHWyMlH8n9jMMdj2XCzV=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-04-29T12:02:52.026941Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTURvaDdha1R3EAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTURvaDdha1R3EAE!2m1!1s0x47a851dd9394c34b:0x8d3f79f5008dab35"
#         },
#         {
#           "name": "places/ChIJS8OUk91RqEcRNauNAPV5P40/reviews/ChZDSUhNMG9nS0VJQ0FnTURROThxY0NBEAE",
#           "relativePublishTimeDescription": "4 months ago",
#           "rating": 4,
#           "text": {
#             "text": "A very interesting museum with an amazing collection of both Egyptian antiquities (a wonderful collection of ancient papyri) and objects from various regions of the world since prehistoric times. The museum presents the timeless evolution of man and his everyday life.Beyond the exhibits, the museum itself is of great interest. Obviously, one visit is not enough to enjoy all this wealth.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "A very interesting museum with an amazing collection of both Egyptian antiquities (a wonderful collection of ancient papyri) and objects from various regions of the world since prehistoric times. The museum presents the timeless evolution of man and his everyday life.Beyond the exhibits, the museum itself is of great interest. Obviously, one visit is not enough to enjoy all this wealth.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Geo Kip",
#             "uri": "https://www.google.com/maps/contrib/100434638758522396630/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocJ6iDgElja7ri75I02dBKJWhvh_3oHCJsmY0b4Te2u-UwBLBA=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2025-03-15T08:05:12.816978Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTURROThxY0NBEAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTURROThxY0NBEAE!2m1!1s0x47a851dd9394c34b:0x8d3f79f5008dab35"
#         }
#       ]
#     },
#     {
#       "formattedAddress": "Bodestra\u00dfe 1-3, 10178 Berlin, Germany",
#       "location": {
#         "latitude": 52.520810399999995,
#         "longitude": 13.398352899999999
#       },
#       "rating": 4.5,
#       "websiteUri": "https://www.smb.museum/museen-einrichtungen/alte-nationalgalerie/home/",
#       "displayName": {
#         "text": "Alte Nationalgalerie",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJM28dat1RqEcRC0AVNUpwAuk/reviews/ChdDSUhNMG9nS0VOR1V5ZTZVaFBEenBRRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "About $14 usd ticket to visit just this museum.\n\nThe bathroom is located down the stairs on the left. You don\u2019t need a ticket to use the bathroom. So you can add this stop as a bathroom break.\n\nAlso there is a nice museum store right before the bathroom. The free lockers are just before the bathroom.  If they are all taken go to the right of the ticket register and there is a free coat check area to check everything you need.\n\nMostly sculptures and some masterpieces. Don\u2019t expect the British Museum or the Met, but it\u2019s a decent sized to spend about 1-2 hours roaming around. We paid and spent 2hrs to see all the collections. There is also a free English tour in the afternoon. Check the time on their website before you go if you want to learn about German art.\n\nDefinitely add as a stop if you\u2019re near Museum Island. Even if just for a restroom break. The grounds have plenty of sculptures you can view for free and sit to enjoy the scenery.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "About $14 usd ticket to visit just this museum.\n\nThe bathroom is located down the stairs on the left. You don\u2019t need a ticket to use the bathroom. So you can add this stop as a bathroom break.\n\nAlso there is a nice museum store right before the bathroom. The free lockers are just before the bathroom.  If they are all taken go to the right of the ticket register and there is a free coat check area to check everything you need.\n\nMostly sculptures and some masterpieces. Don\u2019t expect the British Museum or the Met, but it\u2019s a decent sized to spend about 1-2 hours roaming around. We paid and spent 2hrs to see all the collections. There is also a free English tour in the afternoon. Check the time on their website before you go if you want to learn about German art.\n\nDefinitely add as a stop if you\u2019re near Museum Island. Even if just for a restroom break. The grounds have plenty of sculptures you can view for free and sit to enjoy the scenery.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Luke",
#             "uri": "https://www.google.com/maps/contrib/118000502398007764914/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWR9OIoW7YWSuX5d5XdMuUIqeG-Vh8jmpAB-5LhlJkeVXXLhKybgg=s128-c0x00000000-cc-rp-mo-ba5"
#           },
#           "publishTime": "2025-06-16T14:04:59.423664Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VOR1V5ZTZVaFBEenBRRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VOR1V5ZTZVaFBEenBRRRAB!2m1!1s0x47a851dd6a1d6f33:0xe902704a3515400b"
#         },
#         {
#           "name": "places/ChIJM28dat1RqEcRC0AVNUpwAuk/reviews/Ci9DQUlRQUNvZENodHljRjlvT25OWExXWTVaSEYzV0dwNVVrMDNXbXRVVWpFeGFuYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "A beautiful museum, especially the room dedicated to Caspar David Friedrich. Three floors filled with art from various periods, including great names like Monet, Van Gogh, and Cezanne\u2026",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "A beautiful museum, especially the room dedicated to Caspar David Friedrich. Three floors filled with art from various periods, including great names like Monet, Van Gogh, and Cezanne\u2026",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Michelangelo Ablondi",
#             "uri": "https://www.google.com/maps/contrib/117979901858327777999/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXTc-jkKKNa5vCRN-1K93v7V0Tiyr3PJRSwulgyZPY0KQ9ggtN2=s128-c0x00000000-cc-rp-mo"
#           },
#           "publishTime": "2025-07-18T12:56:20.511106473Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25OWExXWTVaSEYzV0dwNVVrMDNXbXRVVWpFeGFuYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25OWExXWTVaSEYzV0dwNVVrMDNXbXRVVWpFeGFuYxAB!2m1!1s0x47a851dd6a1d6f33:0xe902704a3515400b"
#         },
#         {
#           "name": "places/ChIJM28dat1RqEcRC0AVNUpwAuk/reviews/Ci9DQUlRQUNvZENodHljRjlvT25SRk4yRmZUMUk1YzBKa09WaFJPV2xmVkV4aE0zYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "The most impressive thing in this museum were paintings od french impressionists.\nThere is free bathroom on -1 level. Ticket price is 14 euro for Only this museum.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "The most impressive thing in this museum were paintings od french impressionists.\nThere is free bathroom on -1 level. Ticket price is 14 euro for Only this museum.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Bartek Sztachera",
#             "uri": "https://www.google.com/maps/contrib/112278494858476252212/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIpqyF_apucIQTh_xdiUGGcWxXML9U8GNMWzVeQzc8OCWN0sg=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-07-27T08:10:42.377866121Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25SRk4yRmZUMUk1YzBKa09WaFJPV2xmVkV4aE0zYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25SRk4yRmZUMUk1YzBKa09WaFJPV2xmVkV4aE0zYxAB!2m1!1s0x47a851dd6a1d6f33:0xe902704a3515400b"
#         },
#         {
#           "name": "places/ChIJM28dat1RqEcRC0AVNUpwAuk/reviews/Ci9DQUlRQUNvZENodHljRjlvT21jMVdtUTVWVVZUYWxKclJrTnllRGRwYUZWb0xVRRAB",
#           "relativePublishTimeDescription": "3 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Beautiful museum with lots of winding hallways connecting the rooms so you get lost in the art. Has something for everyone. Latest exhibit, \u201cEmancipation from Rodin,\u201d was carefully curated and very interesting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful museum with lots of winding hallways connecting the rooms so you get lost in the art. Has something for everyone. Latest exhibit, \u201cEmancipation from Rodin,\u201d was carefully curated and very interesting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Sue June Kim",
#             "uri": "https://www.google.com/maps/contrib/101960244403978552226/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWm5x_5QLtzKts0bG5kmky_0XrJfclirREbOzCDM3oFE1SPXdqP=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-07-11T20:18:22.165396429Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21jMVdtUTVWVVZUYWxKclJrTnllRGRwYUZWb0xVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21jMVdtUTVWVVZUYWxKclJrTnllRGRwYUZWb0xVRRAB!2m1!1s0x47a851dd6a1d6f33:0xe902704a3515400b"
#         },
#         {
#           "name": "places/ChIJM28dat1RqEcRC0AVNUpwAuk/reviews/Ci9DQUlRQUNvZENodHljRjlvT21KUmVrczVOVWhCWlZjMlNqZ3dVbTkwTVdseFNIYxAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "This museum has lots of beautiful sculptures, a great place for those who are interested in contemporary and romantic art. Highly recommend it for tourist and those who are interested in art.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "This museum has lots of beautiful sculptures, a great place for those who are interested in contemporary and romantic art. Highly recommend it for tourist and those who are interested in art.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Ali Saremi",
#             "uri": "https://www.google.com/maps/contrib/105791998087268569743/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVI9M-Zqvlpw3kpVIplVGtL-jibB5_JLR5A7uKhoKIXD6p0DaZrYA=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-06-26T20:51:43.470534866Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21KUmVrczVOVWhCWlZjMlNqZ3dVbTkwTVdseFNIYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21KUmVrczVOVWhCWlZjMlNqZ3dVbTkwTVdseFNIYxAB!2m1!1s0x47a851dd6a1d6f33:0xe902704a3515400b"
#         }
#       ]
#     },
#     {
#       "formattedAddress": "Unter den Linden 2, 10117 Berlin, Germany",
#       "location": {
#         "latitude": 52.5186138,
#         "longitude": 13.396359799999999
#       },
#       "rating": 4.5,
#       "websiteUri": "https://www.dhm.de/",
#       "displayName": {
#         "text": "German Historical Museum",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJnZP4HtxRqEcRw0epcRGQ-_k/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZX3MySE9REAE",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 5,
#           "text": {
#             "text": "Only the turning points exhibit was available when I came here but it was a fantastic exhibit about the various points in the past 150 years of German history where things could have gone different. Sometimes for the better, sometimes for the worse, this is a great concept, executed effectively that captures key moments of great history using contemporary media very effectively.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Only the turning points exhibit was available when I came here but it was a fantastic exhibit about the various points in the past 150 years of German history where things could have gone different. Sometimes for the better, sometimes for the worse, this is a great concept, executed effectively that captures key moments of great history using contemporary media very effectively.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "O",
#             "uri": "https://www.google.com/maps/contrib/111416603055324939463/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXALhg66ubo-aTjA0yzBdGvg3qLZA5_F7M3UV-xwQ7w-B__958n=s128-c0x00000000-cc-rp-mo-ba5"
#           },
#           "publishTime": "2025-05-04T17:04:44.833180Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZX3MySE9REAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZX3MySE9REAE!2m1!1s0x47a851dc1ef8939d:0xf9fb901171a947c3"
#         },
#         {
#           "name": "places/ChIJnZP4HtxRqEcRw0epcRGQ-_k/reviews/ChdDSUhNMG9nS0VJQ0FnTURvMU9tcDl3RRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "The German Historical Museum offers a fascinating journey through Germany\u2019s history, particularly focusing on the periods before and after World War II. The exhibitions are thoughtfully curated and provide meaningful insights into the country\u2019s complex past. However, one drawback is that there aren\u2019t a large number of physical artifacts on display. The tour takes about 75 minutes, making it a manageable yet informative visit.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "The German Historical Museum offers a fascinating journey through Germany\u2019s history, particularly focusing on the periods before and after World War II. The exhibitions are thoughtfully curated and provide meaningful insights into the country\u2019s complex past. However, one drawback is that there aren\u2019t a large number of physical artifacts on display. The tour takes about 75 minutes, making it a manageable yet informative visit.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "hamza haddada",
#             "uri": "https://www.google.com/maps/contrib/112042993922170028397/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjW-7-lMcALjrup9_78_ixS8PN21wQn9INGEL6iYgkRyifHeKns3=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-04-22T06:50:04.996964Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTURvMU9tcDl3RRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTURvMU9tcDl3RRAB!2m1!1s0x47a851dc1ef8939d:0xf9fb901171a947c3"
#         },
#         {
#           "name": "places/ChIJnZP4HtxRqEcRw0epcRGQ-_k/reviews/Ci9DQUlRQUNvZENodHljRjlvT201Tk5WbDZWVFZKYzFKa1VISjNXWG96WWw5WE5WRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "We had read good things about the German Historical Museum. Unfortunately, the permanent exhibition was closed due to renovations when we. However, the \u201cRoads not Taken\u201d exhibition in the Pei Building more than made up for it.\n\nIt's a very innovative way to show history - working backwards and lots of \"what ifs\". Additionally, the explanations were clear and well-written. As a result, it's very engaging. I think all four of us read all the panels!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "We had read good things about the German Historical Museum. Unfortunately, the permanent exhibition was closed due to renovations when we. However, the \u201cRoads not Taken\u201d exhibition in the Pei Building more than made up for it.\n\nIt's a very innovative way to show history - working backwards and lots of \"what ifs\". Additionally, the explanations were clear and well-written. As a result, it's very engaging. I think all four of us read all the panels!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Richard Lee",
#             "uri": "https://www.google.com/maps/contrib/102188240326675065037/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWXQwvFK5Wbcx10NNW8Fn2Urt70A7TZb8T79aOlMfVLD3zM4LhOPQ=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-06-26T20:22:58.155927328Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT201Tk5WbDZWVFZKYzFKa1VISjNXWG96WWw5WE5WRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT201Tk5WbDZWVFZKYzFKa1VISjNXWG96WWw5WE5WRRAB!2m1!1s0x47a851dc1ef8939d:0xf9fb901171a947c3"
#         },
#         {
#           "name": "places/ChIJnZP4HtxRqEcRw0epcRGQ-_k/reviews/ChZDSUhNMG9nS0VJQ0FnTUNBNlB1T1l3EAE",
#           "relativePublishTimeDescription": "6 months ago",
#           "rating": 5,
#           "text": {
#             "text": "They are updating their permanent exhibition so I'm glad the new Pei Bau (architect of the Louvre pyramid) is open for some temporary shows. Not sure what others are expecting?\n\nOn the basement they made an effort to tell history in a new way. A lot of What Ifs, like an alternative possibility in history. It reflects a lot of sentiments when things happen - say, what if the assassination (of Hilter) is successful? The layout is cutting edge. The optical illusion layouts seems very innovative, and not too text heavy.\n\nI particularly enjoyed the cold war part and where they draw parallel to the June 4 massacre in Beijing 1989. There was even a well-made iPad graphic novel / interactive game where you can go through what the atmosphere was like in Leipzig in 1989. We will unfortunately never have such storytelling in Hong Kong. So thank you for remembering that part of history.\n\nOn the upper levels there's another exhibition about the enlightenment with older / more traditional exhibits, when science just came into lifes of those in 1700s or so.\n\nA rainy afternoon well spent indoors.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "They are updating their permanent exhibition so I'm glad the new Pei Bau (architect of the Louvre pyramid) is open for some temporary shows. Not sure what others are expecting?\n\nOn the basement they made an effort to tell history in a new way. A lot of What Ifs, like an alternative possibility in history. It reflects a lot of sentiments when things happen - say, what if the assassination (of Hilter) is successful? The layout is cutting edge. The optical illusion layouts seems very innovative, and not too text heavy.\n\nI particularly enjoyed the cold war part and where they draw parallel to the June 4 massacre in Beijing 1989. There was even a well-made iPad graphic novel / interactive game where you can go through what the atmosphere was like in Leipzig in 1989. We will unfortunately never have such storytelling in Hong Kong. So thank you for remembering that part of history.\n\nOn the upper levels there's another exhibition about the enlightenment with older / more traditional exhibits, when science just came into lifes of those in 1700s or so.\n\nA rainy afternoon well spent indoors.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Jen Wan",
#             "uri": "https://www.google.com/maps/contrib/110143603127855350612/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVgcjMgf_2Crjwkxg9GDXP_1DtVuUAJmExLCKpXOzfkS-J7SLkG=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-01-29T09:17:46.047160Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNBNlB1T1l3EAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNBNlB1T1l3EAE!2m1!1s0x47a851dc1ef8939d:0xf9fb901171a947c3"
#         },
#         {
#           "name": "places/ChIJnZP4HtxRqEcRw0epcRGQ-_k/reviews/Ci9DQUlRQUNvZENodHljRjlvT2w5R1FtTmljVzlsWXpoNGFISTJiRzlyYlV0eVZtYxAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 2,
#           "text": {
#             "text": "I have been to several countries in Europe and lots of museums. Never have I had a guard aggressively ask me for a ticket (after already having my pass scanned upstairs) or been denied entrance to a public exhibit. There were 13 minutes left and the exhibit was a smaller one right by the entrance (I had already gone downstairs to see the other one). A few other guests were inside already. Even a 5 minute look would\u2019ve been fine. I understand that there\u2019s a closing time, but it was a strange experience that I couldn\u2019t take a brief look at something right by the exit. The guard who greeted me initially was very nice though.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "I have been to several countries in Europe and lots of museums. Never have I had a guard aggressively ask me for a ticket (after already having my pass scanned upstairs) or been denied entrance to a public exhibit. There were 13 minutes left and the exhibit was a smaller one right by the entrance (I had already gone downstairs to see the other one). A few other guests were inside already. Even a 5 minute look would\u2019ve been fine. I understand that there\u2019s a closing time, but it was a strange experience that I couldn\u2019t take a brief look at something right by the exit. The guard who greeted me initially was very nice though.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Sam Boyd",
#             "uri": "https://www.google.com/maps/contrib/105142249298825497535/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUrDGN7XKUjBusQAOzWc3hlTfbo-7-7zpWrahNKaIHw6Ca3YBRQ=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-06-18T11:23:48.320775528Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2w5R1FtTmljVzlsWXpoNGFISTJiRzlyYlV0eVZtYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2w5R1FtTmljVzlsWXpoNGFISTJiRzlyYlV0eVZtYxAB!2m1!1s0x47a851dc1ef8939d:0xf9fb901171a947c3"
#         }
#       ]
#     },
#     {
#       "formattedAddress": "Vera Britain Ufer, Karl-Liebknecht-Str. 1, 10178 Berlin, Germany",
#       "location": {
#         "latitude": 52.5192243,
#         "longitude": 13.402636999999999
#       },
#       "rating": 4.3,
#       "websiteUri": "https://www.ddr-museum.de/de",
#       "displayName": {
#         "text": "DDR Museum",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJVzpGU95RqEcRZJgnyr-ZDC0/reviews/Ci9DQUlRQUNvZENodHljRjlvT25Ca1YwWkVkblE0WWtsMVdrWjJVSFZTVkZseFpGRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "It showcases key aspects of the former German Democratic Republic in a creative, hands-on way. Each section is carefully set up, and you can interact with almost every display, with clear explanations in both German and English. Open every drawer you see\u2014each one is interactive and hides a surprise, from personal stories to everyday objects that bring the era to life. Original audio clips from the time are in German but sometimes explained in English, so you really grasp what life was like back then. If you want a true sense of daily life in East Germany, from work to home, leisure, and even sports, this is the place. Entry is free with the Berlin Pass, and you\u2019ll need about 60\u201390 minutes to see everything. Highly recommended.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "It showcases key aspects of the former German Democratic Republic in a creative, hands-on way. Each section is carefully set up, and you can interact with almost every display, with clear explanations in both German and English. Open every drawer you see\u2014each one is interactive and hides a surprise, from personal stories to everyday objects that bring the era to life. Original audio clips from the time are in German but sometimes explained in English, so you really grasp what life was like back then. If you want a true sense of daily life in East Germany, from work to home, leisure, and even sports, this is the place. Entry is free with the Berlin Pass, and you\u2019ll need about 60\u201390 minutes to see everything. Highly recommended.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Fabrizio Porreca",
#             "uri": "https://www.google.com/maps/contrib/114868771668784834471/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUL8cI5BIGMCJr9V0cxgDocIHs2cPH2zW2r261chUSSsvXnPO87=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2025-07-02T14:57:23.105505149Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25Ca1YwWkVkblE0WWtsMVdrWjJVSFZTVkZseFpGRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25Ca1YwWkVkblE0WWtsMVdrWjJVSFZTVkZseFpGRRAB!2m1!1s0x47a851de53463a57:0x2d0c99bfca279864"
#         },
#         {
#           "name": "places/ChIJVzpGU95RqEcRZJgnyr-ZDC0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pGdlVtNVRlV05mWTI1WVNGVjRhbXN0T1RSSVNHYxAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "It was recommended that we visit this museum to learn\nwhat life was like for the German people. This was a very good opportunity to see what people lived through during that time. The museum is very interactive, so you can actually get involved in some of the activities. You can also dress up in some of the costumes that were available.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "It was recommended that we visit this museum to learn\nwhat life was like for the German people. This was a very good opportunity to see what people lived through during that time. The museum is very interactive, so you can actually get involved in some of the activities. You can also dress up in some of the costumes that were available.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Bill Howe",
#             "uri": "https://www.google.com/maps/contrib/114509691765367045152/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjX9BXBaMySIUQncDdylFEky41sUTBN1R7jl-aJl1dbtS8_yJoreDQ=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2025-06-26T19:07:20.047903699Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pGdlVtNVRlV05mWTI1WVNGVjRhbXN0T1RSSVNHYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pGdlVtNVRlV05mWTI1WVNGVjRhbXN0T1RSSVNHYxAB!2m1!1s0x47a851de53463a57:0x2d0c99bfca279864"
#         },
#         {
#           "name": "places/ChIJVzpGU95RqEcRZJgnyr-ZDC0/reviews/Ci9DQUlRQUNvZENodHljRjlvT25aeVEwdFhkbFZJTXpsWE1rNUpjMEpKUVVSeUxVRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "Highly recommend this extremely interactive and educational museum! The exhibits were hands-on and very interesting. The Trabant driving simulator was a bit confusing to work out though. The museum gives a pretty good idea of what life was like in East Germany especially through the recreation of the average apartment. The electronic displays with information had many languages to choose from, and the interactive electronic exhibits were well made.\nIt takes about 1.5-2 hours to get through all the exhibits.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Highly recommend this extremely interactive and educational museum! The exhibits were hands-on and very interesting. The Trabant driving simulator was a bit confusing to work out though. The museum gives a pretty good idea of what life was like in East Germany especially through the recreation of the average apartment. The electronic displays with information had many languages to choose from, and the interactive electronic exhibits were well made.\nIt takes about 1.5-2 hours to get through all the exhibits.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Jerry Huang",
#             "uri": "https://www.google.com/maps/contrib/105626765446716953297/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI-gHH1bQ_e8_zOnR-8s-luNtbUW1a8NtSE6TwHUv6Fth9log=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-07-05T07:35:10.632546782Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25aeVEwdFhkbFZJTXpsWE1rNUpjMEpKUVVSeUxVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25aeVEwdFhkbFZJTXpsWE1rNUpjMEpKUVVSeUxVRRAB!2m1!1s0x47a851de53463a57:0x2d0c99bfca279864"
#         },
#         {
#           "name": "places/ChIJVzpGU95RqEcRZJgnyr-ZDC0/reviews/Ci9DQUlRQUNvZENodHljRjlvT25kWU1FWlNNSGRWUm5CNWVWRk1jbXhXWmpkelRIYxAB",
#           "relativePublishTimeDescription": "3 weeks ago",
#           "rating": 4,
#           "text": {
#             "text": "I\u2019d give the DDR Museum 4 stars because, while it was definitely interesting and well put together, I personally felt it was a bit overpriced. The entry fee was \u20ac13, but the museum only has one main floor, and I finished seeing everything in about 15 minutes.\n\nThe interactive exhibits were engaging, and it gives a good glimpse into East German life \u2014 no doubt worth seeing if you\u2019re curious about the GDR era. However, for the price, I expected a bit more to explore.\n\nThat said, this was just my experience \u2014 it could vary from person to person depending on how much time you like to spend reading and interacting with exhibits.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "I\u2019d give the DDR Museum 4 stars because, while it was definitely interesting and well put together, I personally felt it was a bit overpriced. The entry fee was \u20ac13, but the museum only has one main floor, and I finished seeing everything in about 15 minutes.\n\nThe interactive exhibits were engaging, and it gives a good glimpse into East German life \u2014 no doubt worth seeing if you\u2019re curious about the GDR era. However, for the price, I expected a bit more to explore.\n\nThat said, this was just my experience \u2014 it could vary from person to person depending on how much time you like to spend reading and interacting with exhibits.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Maria Garza",
#             "uri": "https://www.google.com/maps/contrib/117874118878810047674/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocKhlPOED1j-L40Z_HxPgQD0_GQXId-bv8Wdw201CehuQH37_Q=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-07-08T16:24:52.253726547Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25kWU1FWlNNSGRWUm5CNWVWRk1jbXhXWmpkelRIYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25kWU1FWlNNSGRWUm5CNWVWRk1jbXhXWmpkelRIYxAB!2m1!1s0x47a851de53463a57:0x2d0c99bfca279864"
#         },
#         {
#           "name": "places/ChIJVzpGU95RqEcRZJgnyr-ZDC0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2psNFNUVnFlV0p6VkhWVWIyOVpabTlJYkZKc09WRRAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 3,
#           "text": {
#             "text": "really interesting museum. Unfortunately thought it was very overcrowded so you couldn\u2019t view all of the material and also quite expensive for entry considering how small it is which is a shame. I would also recommend buying tickets online as there was a long wait to buy them",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "really interesting museum. Unfortunately thought it was very overcrowded so you couldn\u2019t view all of the material and also quite expensive for entry considering how small it is which is a shame. I would also recommend buying tickets online as there was a long wait to buy them",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "zaz o",
#             "uri": "https://www.google.com/maps/contrib/102685919703641380768/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIggaQnB0v90zB-Yx-0xiTMLq2xOWUupXPHay2KdVV28bYGBA=s128-c0x00000000-cc-rp-mo"
#           },
#           "publishTime": "2025-07-28T15:19:16.796212872Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2psNFNUVnFlV0p6VkhWVWIyOVpabTlJYkZKc09WRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2psNFNUVnFlV0p6VkhWVWIyOVpabTlJYkZKc09WRRAB!2m1!1s0x47a851de53463a57:0x2d0c99bfca279864"
#         }
#       ]
#     },
#     {
#       "formattedAddress": "Bodestra\u00dfe 1-3, 10178 Berlin, Germany",
#       "location": {
#         "latitude": 52.5194665,
#         "longitude": 13.398744500000001
#       },
#       "rating": 4.6,
#       "websiteUri": "https://www.smb.museum/museen-einrichtungen/altes-museum/home/",
#       "displayName": {
#         "text": "Altes Museum",
#         "languageCode": "de"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJM28dat1RqEcRu_1H_QZRHrY/reviews/Ci9DQUlRQUNvZENodHljRjlvT2s1RFJuRkJhRmRJT1VGUlVrdzVRelJ6ZDFvdFpWRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 4,
#           "text": {
#             "text": "It sits at the far end of a lovely park, close to Berlin\u2019s main sights, and houses antiquities from Greece, Rome, the wider Roman Empire, and Etruria. The collection is impressive: everything from tools and weapons to statues and sculptures, displayed in beautiful rooms. I give it four stars only because staff start shutting sections well before closing time and can rush visitors out, which feels stressful if you arrive late. Plan to visit early in the day to enjoy it at your own pace.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "It sits at the far end of a lovely park, close to Berlin\u2019s main sights, and houses antiquities from Greece, Rome, the wider Roman Empire, and Etruria. The collection is impressive: everything from tools and weapons to statues and sculptures, displayed in beautiful rooms. I give it four stars only because staff start shutting sections well before closing time and can rush visitors out, which feels stressful if you arrive late. Plan to visit early in the day to enjoy it at your own pace.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Fabrizio Porreca",
#             "uri": "https://www.google.com/maps/contrib/114868771668784834471/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUL8cI5BIGMCJr9V0cxgDocIHs2cPH2zW2r261chUSSsvXnPO87=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2025-07-03T14:41:20.934342427Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2s1RFJuRkJhRmRJT1VGUlVrdzVRelJ6ZDFvdFpWRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2s1RFJuRkJhRmRJT1VGUlVrdzVRelJ6ZDFvdFpWRRAB!2m1!1s0x47a851dd6a1d6f33:0xb61e5106fd47fdbb"
#         },
#         {
#           "name": "places/ChIJM28dat1RqEcRu_1H_QZRHrY/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xsME1HaFBjakZrYlZsS2RuVjRNR2RrU2t3NFMxRRAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "Neues Museum, located on Berlin\u2019s Museum Island, is a true gem for anyone interested in archaeology, ancient civilizations, and world history. The museum\u2019s architecture alone is worth the visit\u2014beautifully restored after World War II damage, it strikes a perfect balance between historical preservation and modern design.\nThe collection is rich and diverse, spanning from prehistoric artifacts to Ancient Egyptian treasures. The star of the museum is undoubtedly the famous bust of Nefertiti\u2014breathtakingly elegant and displayed with the respect it deserves. You\u2019ll also find fascinating exhibits from the Roman and Greek periods, as well as early European history.\nThe layout is thoughtfully organized, and the multilingual descriptions make it accessible for international visitors. Plan to spend at least 1.5 to 2 hours here if you want to explore thoroughly.\nNeues Museum isn\u2019t just a museum\u2014it\u2019s a journey through thousands of years of human history. If you\u2019re in Berlin and even remotely curious about ancient cultures, this place should definitely be on your list.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Neues Museum, located on Berlin\u2019s Museum Island, is a true gem for anyone interested in archaeology, ancient civilizations, and world history. The museum\u2019s architecture alone is worth the visit\u2014beautifully restored after World War II damage, it strikes a perfect balance between historical preservation and modern design.\nThe collection is rich and diverse, spanning from prehistoric artifacts to Ancient Egyptian treasures. The star of the museum is undoubtedly the famous bust of Nefertiti\u2014breathtakingly elegant and displayed with the respect it deserves. You\u2019ll also find fascinating exhibits from the Roman and Greek periods, as well as early European history.\nThe layout is thoughtfully organized, and the multilingual descriptions make it accessible for international visitors. Plan to spend at least 1.5 to 2 hours here if you want to explore thoroughly.\nNeues Museum isn\u2019t just a museum\u2014it\u2019s a journey through thousands of years of human history. If you\u2019re in Berlin and even remotely curious about ancient cultures, this place should definitely be on your list.",
#             "languageCode": "en"
#           },
# ...
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "A powerful and emotional place to visit. The Berlin Wall Memorial offers a deep insight into the city\u2019s divided past. The preserved section of the wall, watchtower, and detailed exhibits tell the stories of those affected by the separation. Walking along the open-air site feels moving and reflective. The information boards are clear and engaging, available in multiple languages. It\u2019s not just a monument, but a reminder of history and hope. Highly recommended for anyone wanting to understand Berlin\u2019s past beyond just seeing the wall itself. A must-visit for history lovers and thoughtful travelers alike.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Mahesh Kara",
#             "uri": "https://www.google.com/maps/contrib/110581924972206456445/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXUWwJNB9shAMDT3W4ACW7Ltjct1z_B3KPZPLFqgYOFNOABuU3Isw=s128-c0x00000000-cc-rp-mo-ba5"
#           },
#           "publishTime": "2025-06-28T15:11:43.155168211Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25sdlVDMUlRek0zUjJGblVESnpTM1U0WWpSa0xWRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25sdlVDMUlRek0zUjJGblVESnpTM1U0WWpSa0xWRRAB!2m1!1s0x47a851f217b14267:0xea53fe8afbc1b1ac"
#         },
#         {
#           "name": "places/ChIJZ0KxF_JRqEcRrLHB-4r-U-o/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xWT1lWQnNjbG8zVFRCWE4xZFBOa1JMVERsWmExRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "It keeps alive the memories of those whose lives were shaped by the Wall, illustrating its impact on families and everyday life. After the park, visit the nearby exhibition: it tells detailed personal stories from both sides of reunification and is beautifully curated. A few video stations were out of order, yet the overall presentation is so thorough that I still give it five stars. Highly recommended if you want to grasp Berlin\u2019s history up close.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "It keeps alive the memories of those whose lives were shaped by the Wall, illustrating its impact on families and everyday life. After the park, visit the nearby exhibition: it tells detailed personal stories from both sides of reunification and is beautifully curated. A few video stations were out of order, yet the overall presentation is so thorough that I still give it five stars. Highly recommended if you want to grasp Berlin\u2019s history up close.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Fabrizio Porreca",
#             "uri": "https://www.google.com/maps/contrib/114868771668784834471/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUL8cI5BIGMCJr9V0cxgDocIHs2cPH2zW2r261chUSSsvXnPO87=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2025-07-04T14:56:27.997942459Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xWT1lWQnNjbG8zVFRCWE4xZFBOa1JMVERsWmExRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xWT1lWQnNjbG8zVFRCWE4xZFBOa1JMVERsWmExRRAB!2m1!1s0x47a851f217b14267:0xea53fe8afbc1b1ac"
#         },
#         {
#           "name": "places/ChIJZ0KxF_JRqEcRrLHB-4r-U-o/reviews/Ci9DQUlRQUNvZENodHljRjlvT2w5WVVXTnhTMDU1V25ORk4wUmhSMnQxVVVWU1RVRRAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 5,
#           "text": {
#             "text": "Take the walk and visit each section. There are remnants of the wall, structures and the steel supports still standing. Along the way are information plaques and pictures that provide more historical information. It\u2019s somber to see and think about those impacted at the time. Worth the visit.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Take the walk and visit each section. There are remnants of the wall, structures and the steel supports still standing. Along the way are information plaques and pictures that provide more historical information. It\u2019s somber to see and think about those impacted at the time. Worth the visit.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Jae",
#             "uri": "https://www.google.com/maps/contrib/110910252910054829658/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocKHR9Fu-tlNFJ0AQK5sFA4AmDDMjA1X1fLg33oJbOSdfE9TbA=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-06-25T00:51:48.163179711Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2w5WVVXTnhTMDU1V25ORk4wUmhSMnQxVVVWU1RVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2w5WVVXTnhTMDU1V25ORk4wUmhSMnQxVVVWU1RVRRAB!2m1!1s0x47a851f217b14267:0xea53fe8afbc1b1ac"
#         },
#         {
#           "name": "places/ChIJZ0KxF_JRqEcRrLHB-4r-U-o/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSd2JHbEZTblo1ZVVsQ1owVkJXa2QzVlcxalVXYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Great sad history, well preserved and and tell a tale story of struggles  of break and unification. And well acknowledged and respect for the country and resilience of the people. Make sure which part of the walk you want to go.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Great sad history, well preserved and and tell a tale story of struggles  of break and unification. And well acknowledged and respect for the country and resilience of the people. Make sure which part of the walk you want to go.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "raV v",
#             "uri": "https://www.google.com/maps/contrib/106537603375301499381/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjU6GTtWeJtxdnEAcPkQYfibsqY1UuCZiKxC5WKy3o2For0z80cdng=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-07-17T14:38:26.947594512Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSd2JHbEZTblo1ZVVsQ1owVkJXa2QzVlcxalVXYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSd2JHbEZTblo1ZVVsQ1owVkJXa2QzVlcxalVXYxAB!2m1!1s0x47a851f217b14267:0xea53fe8afbc1b1ac"
#         }
#       ]
#     },
#     {
#       "formattedAddress": "Unter den Linden 74, 10117 Berlin, Germany",
#       "location": {
#         "latitude": 52.5168889,
#         "longitude": 13.381591799999999
#       },
#       "rating": 4.3,
#       "websiteUri": "https://www.madametussauds.com/berlin/de/",
#       "displayName": {
#         "text": "Madame Tussauds Berlin",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJr-gAJ8RRqEcR2Ml0N1JXFu4/reviews/ChZDSUhNMG9nS0VQNzc1NV9aemV1MVJREAE",
#           "relativePublishTimeDescription": "2 months ago",
#           "rating": 5,
#           "text": {
#             "text": "A fun and interactive experience! Get up close with lifelike wax figures of celebrities, historical figures, and athletes. Great for photos and family-friendly entertainment in the heart of Berlin.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "A fun and interactive experience! Get up close with lifelike wax figures of celebrities, historical figures, and athletes. Great for photos and family-friendly entertainment in the heart of Berlin.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Alin Bocu",
#             "uri": "https://www.google.com/maps/contrib/112931485623494026004/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWuXoUWEx2-MOLR6ISAN37bt4WFY7I85ZeoPkGxBnm-85f0hpJD=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-19T16:15:00.459378Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VQNzc1NV9aemV1MVJREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VQNzc1NV9aemV1MVJREAE!2m1!1s0x47a851c42700e8af:0xee1657523774c9d8"
#         },
#         {
#           "name": "places/ChIJr-gAJ8RRqEcR2Ml0N1JXFu4/reviews/ChZDSUhNMG9nS0VJQ0FnSURmcnEyaFhBEAE",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 5,
#           "text": {
#             "text": "I had a wonderful time visiting Madame Tussauds Berlin! The figures are incredibly lifelike, making it a fun experience for all ages. It's a great place to take memorable photos with your favorite celebrities and historical icons. The location near the Brandenburg Gate is perfect for tourists exploring the city. Highly recommended for a fun and unique outing in Berlin!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "I had a wonderful time visiting Madame Tussauds Berlin! The figures are incredibly lifelike, making it a fun experience for all ages. It's a great place to take memorable photos with your favorite celebrities and historical icons. The location near the Brandenburg Gate is perfect for tourists exploring the city. Highly recommended for a fun and unique outing in Berlin!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Khushe Motemani",
#             "uri": "https://www.google.com/maps/contrib/116698174715605071754/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVonZkbrkvC1B2PdgJKI2mgdxxHGVatC6j9HiCLgaZZ3Lswjixx=s128-c0x00000000-cc-rp-mo-ba5"
#           },
#           "publishTime": "2025-01-06T18:27:25.959132Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnSURmcnEyaFhBEAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnSURmcnEyaFhBEAE!2m1!1s0x47a851c42700e8af:0xee1657523774c9d8"
#         },
#         {
#           "name": "places/ChIJr-gAJ8RRqEcR2Ml0N1JXFu4/reviews/ChdDSUhNMG9nS0VJQ0FnTURJNnUyeTFRRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 5,
#           "text": {
#             "text": "I\u2019ve been to a few Madame Tussauds locations, and the one in Berlin definitely held its own. The layout was well organized, and the variety of figures was solid, from historical icons to modern celebs. I especially liked the Berlin specific touches, which gave it a nice local feel. The staff were helpful and the whole experience felt smooth and fun. I really enjoyed my time there.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "I\u2019ve been to a few Madame Tussauds locations, and the one in Berlin definitely held its own. The layout was well organized, and the variety of figures was solid, from historical icons to modern celebs. I especially liked the Berlin specific touches, which gave it a nice local feel. The staff were helpful and the whole experience felt smooth and fun. I really enjoyed my time there.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Eric L",
#             "uri": "https://www.google.com/maps/contrib/116550142653090461484/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUcPy6mLzJHhpPX5amyEzH-ll_Qv1rmtsT9_oE19KbU43zdSxu5=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-04-08T23:36:01.197612Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTURJNnUyeTFRRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTURJNnUyeTFRRRAB!2m1!1s0x47a851c42700e8af:0xee1657523774c9d8"
#         },
#         {
#           "name": "places/ChIJr-gAJ8RRqEcR2Ml0N1JXFu4/reviews/ChZDSUhNMG9nS0VJQ0FnSUNmN1lqa0tnEAE",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 5,
#           "text": {
#             "text": "Great fun and a great museum! I was in the same museum in Budapest and I can say that this one is much bigger! At the end, you have a small souvenir shop, but don't be fooled, after it you have another one that is not related to the museum itself.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Great fun and a great museum! I was in the same museum in Budapest and I can say that this one is much bigger! At the end, you have a small souvenir shop, but don't be fooled, after it you have another one that is not related to the museum itself.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Sveto Rakovic",
#             "uri": "https://www.google.com/maps/contrib/109687529476971000821/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXELv1h6KNSxjLBZ4irfEkGKjzrypoUHg3izpRjZZ_yFLu388A=s128-c0x00000000-cc-rp-mo-ba6"
#           },
#           "publishTime": "2024-12-31T17:14:45.188744Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnSUNmN1lqa0tnEAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnSUNmN1lqa0tnEAE!2m1!1s0x47a851c42700e8af:0xee1657523774c9d8"
#         },
#         {
#           "name": "places/ChIJr-gAJ8RRqEcR2Ml0N1JXFu4/reviews/Ci9DQUlRQUNvZENodHljRjlvT2t0cVMwOHdSRFJLWkhKNVlXZFRTMHQ2Y1hOUlpIYxAB",
#           "relativePublishTimeDescription": "a month ago",
#           "rating": 3,
#           "text": {
#             "text": "Many figurine has a german origin so we  didnt know them, we advice to come around 17.30 when it wasnt so busy",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Many figurine has a german origin so we  didnt know them, we advice to come around 17.30 when it wasnt so busy",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Andrea Legenyova",
#             "uri": "https://www.google.com/maps/contrib/115553462584417935978/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOGAJlshBbUva3UX_dDSNh0hNTrfFJmiMVlWNuo2sT9sx2hjB8ZA=s128-c0x00000000-cc-rp-mo-ba5"
#           },
#           "publishTime": "2025-07-02T15:23:39.617689796Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2t0cVMwOHdSRFJLWkhKNVlXZFRTMHQ2Y1hOUlpIYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2t0cVMwOHdSRFJLWkhKNVlXZFRTMHQ2Y1hOUlpIYxAB!2m1!1s0x47a851c42700e8af:0xee1657523774c9d8"
#         }
#       ]
#     }
#   ]
# }
